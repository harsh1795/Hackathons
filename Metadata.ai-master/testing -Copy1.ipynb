# %%
import pandas
URL = 'ge_titles.csv'
df_training = pandas.read_csv(URL)

# %%
df_DUM = pandas.read_csv(URL)

# %%
df_DUM['Age'] = map(int,list(np.random.normal(26,8,2)))
df_DUM['BP'] = map(int,list(np.random.normal(120,60,2)))
df_DUM['Sugar'] = map(int,list(np.random.normal(8,5,2)))
df_DUM['Drug'] = [random.randrange(1,5) for _ in range(0,2)]
df_DUM['Weight gain'] = [random.randrange(1,50) for _ in range(0,2)]
df_DUM['Weight gain /Week'] = [random.randrange(1,10) for _ in range(0,2)]
df_DUM['Blood group'] = [random.randrange(1,4) for _ in range(0,2)]

df_DUM['Bleeding Times'] = [random.randrange(1,20) for _ in range(0,2)]
df_DUM['JVP'] = [random.randrange(1,10) for _ in range(0,2)]
df_DUM['TPR'] = [random.randrange(1,10) for _ in range(0,2)]
df_DUM['dio-femoral delay'] = [random.randrange(1,10) for _ in range(0,2)]
df_DUM['Respiratory Rate'] = [random.randrange(1,10) for _ in range(0,2)]
for i in Categs:
    df_DUM[i]=["Yes","No"]

df_DUM['L11P'] = Randompred2()[:2]
df_DUM['L11A'] = Randompred2()[:2]
df_DUM['L21P'] = Randompred3()[:2]
df_DUM['L21A'] = Randompred3()[:2]
df_DUM['L22P'] = Randompred3()[:2]
df_DUM['L22A'] = Randompred3()[:2]
df_DUM['L23P'] = Randompred3()[:2]
df_DUM['L23A'] = Randompred3()[:2]
df_DUM['L24P'] = Randompred3()[:2]
df_DUM['L24A'] = Randompred3()[:2]
df_DUM['L31P'] = Randompred4()[:2]
df_DUM['L31A'] = Randompred4()[:2]
df_DUM['L32P'] = Randompred4()[:2]
df_DUM['L32A'] = Randompred4()[:2]
df_DUM['L33P'] = Randompred4()[:2]
df_DUM['L33A'] = Randompred4()[:2]

# %%
df_DUM.to_csv('DUMB.csv')

# %%
Categs = ['Morning Sickness','Breast discomfort','UTI Burning maturation','H/0 Fever','edema','Quickening','Drugs','Abdominal pain','Ultra Sound','hyper Tension'
 ,'Bleeding','Sudden in Weight','Thyroid swelling','UTI last stage',
 'Backache','Labour pain','Blurring','Contraseption used','Fetal moments','any deficit']

import random
def Randomlist():
    A = ["Yes","No"]
    BOLlist = []
    for i in range(1000):
        BOLlist.append(random.choice(A))
    return BOLlist
def Randompred2():
    A = ["21","22",'23','24']
    Prelev2 = []
    for i in range(1000):
        Prelev2.append(random.choice(A))
    return Prelev2

def Randompred3():
    A = ["31","32",'33']
    Prelev3 = []
    for i in range(1000):
        Prelev3.append(random.choice(A))
    return Prelev3

for i in Categs:
    df_training[i] = Randomlist()

def Randompred4():
    A = ["1","0",]
    Prelev4 = []
    for i in range(1000):
        Prelev4.append(random.choice(A))
    return Prelev4
    
import numpy as np

df_training['L11P'] = Randompred2()
df_training['L11A'] = Randompred2()
df_training['L21P'] = Randompred3()
df_training['L21A'] = Randompred3()
df_training['L22P'] = Randompred3()
df_training['L22A'] = Randompred3()
df_training['L23P'] = Randompred3()
df_training['L23A'] = Randompred3()
df_training['L24P'] = Randompred3()
df_training['L24A'] = Randompred3()
df_training['L31P'] = Randompred4()
df_training['L31A'] = Randompred4()
df_training['L32P'] = Randompred4()
df_training['L32A'] = Randompred4()
df_training['L33P'] = Randompred4()
df_training['L33A'] = Randompred4()


df_training['Age'] = map(int,list(np.random.normal(26,8,1000)))
df_training['BP'] = map(int,list(np.random.normal(120,60,1000)))
df_training['Sugar'] = map(int,list(np.random.normal(8,5,1000)))
df_training['Drug'] = [random.randrange(1,5) for _ in range(0,1000)]
df_training['Weight gain'] = [random.randrange(1,50) for _ in range(0,1000)]
df_training['Weight gain /Week'] = [random.randrange(1,10) for _ in range(0,1000)]
df_training['Blood group'] = [random.randrange(1,4) for _ in range(0,1000)]

df_training['Bleeding Times'] = [random.randrange(1,20) for _ in range(0,1000)]
df_training['JVP'] = [random.randrange(1,10) for _ in range(0,1000)]
df_training['TPR'] = [random.randrange(1,10) for _ in range(0,1000)]
df_training['dio-femoral delay'] = [random.randrange(1,10) for _ in range(0,1000)]
df_training['Respiratory Rate'] = [random.randrange(1,10) for _ in range(0,1000)]

# %%
#Model 
df_training.columns[:]
#Basic
df_training.columns[:7]
#L21
list(df_training.columns[:6])+ list(df_training.columns[8:14])
#L22
list(df_training.columns[:6])+ list(df_training.columns[15:20])
#L23
list(df_training.columns[:6])+ list(df_training.columns[21:26])
#L24
list(df_training.columns[:6])+ list(df_training.columns[27:32])
#L31
list(df_training.columns[33:37])
#L32
list(df_training.columns[38:42])
#L33
list(df_training.columns[43:47])

# %%
list(df_training.columns[38:42])

# %%
#BasicFuntion Night 
df_train = df_training[df_training.columns[:7]]
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
Y_train = df_train['L11P'].values
del df_train['L11P']
#ENCODING
X_train = df_train.to_dict('records')
X_tr = []
X_tr.extend(X_train)
#One Hot Encoding 
enc = DictVectorizer(sparse = True)
X_encoded_train =enc.fit_transform(X_tr)
estimator = GradientBoostingClassifier() 
estimator.fit(X_encoded_train.toarray(),Y_train)
from sklearn.externals import joblib
joblib.dump(estimator, 'Estbasic.pkl')

# %%
#BasicFuntion predict 
from sklearn.externals import joblib
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[df_training.columns[:7]]
df_test = df_train[3:4]
frames = [ df_DUMB,df_test]
df_WH = pd.concat(frames)

#ENCODING
del df_WH['L11P']
X_test = df_WH.to_dict('records')
X_te = []
X_te.extend(X_test)


encoder = DictVectorizer(sparse = True)
X_encoded_test = encoder.fit_transform(X_te)
clf2 = joblib.load('Estbasic.pkl') 
Predictions = clf2.predict(X_encoded_test.toarray()[-1])
print Predictions

# %%
df_test

# %%
#L21 Night 
df_train = df_training[list(df_training.columns[:6])+ list(df_training.columns[8:14])]
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
Y_train = df_train['L21P'].values
del df_train['L21P']
#ENCODING
X_train = df_train.to_dict('records')
X_tr = []
X_tr.extend(X_train)
#One Hot Encoding 
enc = DictVectorizer(sparse = True)
X_encoded_train =enc.fit_transform(X_tr)
estimator = GradientBoostingClassifier() 
estimator.fit(X_encoded_train.toarray(),Y_train)
from sklearn.externals import joblib
joblib.dump(estimator, 'EstL21.pkl')

# %%
#L22 predict  
from sklearn.externals import joblib
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[list(df_training.columns[:6])+ list(df_training.columns[8:14])]
df_test = df_train[:1]
frames = [ df_DUMB,df_test]
df_WH = pd.concat(frames)

#ENCODING
del df_WH['L21P']
X_test = df_WH.to_dict('records')
X_te = []
X_te.extend(X_test)


encoder = DictVectorizer(sparse = True)
X_encoded_test = encoder.fit_transform(X_te)
clf2 = joblib.load('EstL21.pkl') 
Predictions = clf2.predict(X_encoded_test.toarray()[-1])
print Predictions

# %%
#L22 Night 
df_train = df_training[list(df_training.columns[:6])+ list(df_training.columns[15:20])]
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
Y_train = df_train['L22P'].values
del df_train['L22P']
#ENCODING
X_train = df_train.to_dict('records')
X_tr = []
X_tr.extend(X_train)
#One Hot Encoding 
enc = DictVectorizer(sparse = True)
X_encoded_train =enc.fit_transform(X_tr)
estimator = GradientBoostingClassifier() 
estimator.fit(X_encoded_train.toarray(),Y_train)
from sklearn.externals import joblib
joblib.dump(estimator, 'EstL22.pkl')

# %%
#L22 predict  
from sklearn.externals import joblib
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[list(df_training.columns[:6])+ list(df_training.columns[15:20])]
df_test = df_train[:1]
frames = [ df_DUMB,df_test]
df_WH = pd.concat(frames)

#ENCODING
del df_WH['L22P']
X_test = df_WH.to_dict('records')
X_te = []
X_te.extend(X_test)


encoder = DictVectorizer(sparse = True)
X_encoded_test = encoder.fit_transform(X_te)
clf2 = joblib.load('EstL22.pkl') 
Predictions = clf2.predict(X_encoded_test.toarray()[-1])
print Predictions

# %%
#L23 Night 
df_train = df_training[list(df_training.columns[:6])+ list(df_training.columns[21:26])]
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
Y_train = df_train['L23P'].values
del df_train['L23P']
#ENCODING
X_train = df_train.to_dict('records')
X_tr = []
X_tr.extend(X_train)
#One Hot Encoding 
enc = DictVectorizer(sparse = True)
X_encoded_train =enc.fit_transform(X_tr)
estimator = GradientBoostingClassifier() 
estimator.fit(X_encoded_train.toarray(),Y_train)
from sklearn.externals import joblib
joblib.dump(estimator, 'EstL23.pkl')

# %%
#L23 predict  
from sklearn.externals import joblib
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[list(df_training.columns[:6])+ list(df_training.columns[21:26])]
df_test = df_train[:1]
frames = [ df_DUMB,df_test]
df_WH = pd.concat(frames)

#ENCODING
del df_WH['L23P']
X_test = df_WH.to_dict('records')
X_te = []
X_te.extend(X_test)


encoder = DictVectorizer(sparse = True)
X_encoded_test = encoder.fit_transform(X_te)
clf2 = joblib.load('EstL23.pkl') 
Predictions = clf2.predict(X_encoded_test.toarray()[-1])
print Predictions

# %%
#L24 Night 
df_train = df_training[list(df_training.columns[:6])+ list(df_training.columns[27:32])]
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
Y_train = df_train['L24P'].values
del df_train['L24P']
#ENCODING
X_train = df_train.to_dict('records')
X_tr = []
X_tr.extend(X_train)
#One Hot Encoding 
enc = DictVectorizer(sparse = True)
X_encoded_train =enc.fit_transform(X_tr)
estimator = GradientBoostingClassifier() 
estimator.fit(X_encoded_train.toarray(),Y_train)
from sklearn.externals import joblib
joblib.dump(estimator, 'EstL24.pkl')

# %%
#L24 predict  
from sklearn.externals import joblib
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[list(df_training.columns[:6])+ list(df_training.columns[27:32])]
df_test = df_train[3:4]
frames = [ df_DUMB,df_test]
df_WH = pd.concat(frames)

#ENCODING
del df_WH['L24P']
X_test = df_WH.to_dict('records')
X_te = []
X_te.extend(X_test)


encoder = DictVectorizer(sparse = True)
X_encoded_test = encoder.fit_transform(X_te)
clf2 = joblib.load('EstL24.pkl') 
Predictions = clf2.predict(X_encoded_test.toarray()[-1])
print Predictions

# %%
N='22'
if N == '21':
    Questions = list(df_training.columns[:6])+ list(df_training.columns[8:15])
elif N=='22':
    Questions = list(df_training.columns[:6])+ list(df_training.columns[15:19])
elif N=='23':
    Questions = list(df_training.columns[:6])+ list(df_training.columns[21:25])
else:
    Questions = list(df_training.columns[:6])+ list(df_training.columns[27:31])

# %%
Questions = list(df_training.columns[:6])+ list(df_training.columns[27:31])

# %%
#L31 Night 
df_train = df_training[Questions+list(df_training.columns[33:37])]
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
Y_train = df_train['L31P'].values
del df_train['L31P']
#ENCODING
X_train = df_train.to_dict('records')
X_tr = []
X_tr.extend(X_train)
#One Hot Encoding 
enc = DictVectorizer(sparse = True)
X_encoded_train =enc.fit_transform(X_tr)
estimator = GradientBoostingClassifier() 
estimator.fit(X_encoded_train.toarray(),Y_train)
from sklearn.externals import joblib
joblib.dump(estimator, 'EstL31.pkl')

# %%
#L31 predict  
from sklearn.externals import joblib
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[Questions+list(df_training.columns[33:37])]
df_test = df_train[1:2]
frames = [ df_DUMB,df_test]
df_WH = pd.concat(frames)

#ENCODING
del df_WH['L31P']
X_test = df_WH.to_dict('records')
X_te = []
X_te.extend(X_test)


encoder = DictVectorizer(sparse = True)
X_encoded_test = encoder.fit_transform(X_te)
clf2 = joblib.load('EstL31.pkl') 
Predictions = clf2.predict(X_encoded_test.toarray()[-1])
print Predictions

# %%
list(df_training.columns[33:37])
#L32
list(df_training.columns[38:42])
#L33
list(df_training.columns[43:47])

# %%
#L32 Night 
df_train = df_training[Questions+list(df_training.columns[38:42])]
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
Y_train = df_train['L32P'].values
del df_train['L32P']
#ENCODING
X_train = df_train.to_dict('records')
X_tr = []
X_tr.extend(X_train)
#One Hot Encoding 
enc = DictVectorizer(sparse = True)
X_encoded_train =enc.fit_transform(X_tr)
estimator = GradientBoostingClassifier() 
estimator.fit(X_encoded_train.toarray(),Y_train)
from sklearn.externals import joblib
joblib.dump(estimator, 'EstL32.pkl')

# %%
#L32 predict  
from sklearn.externals import joblib
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[Questions+list(df_training.columns[38:42])]
df_test = df_train[1:2]
frames = [ df_DUMB,df_test]
df_WH = pd.concat(frames)

#ENCODING
del df_WH['L32P']
X_test = df_WH.to_dict('records')
X_te = []
X_te.extend(X_test)


encoder = DictVectorizer(sparse = True)
X_encoded_test = encoder.fit_transform(X_te)
clf2 = joblib.load('EstL32.pkl') 
Predictions = clf2.predict(X_encoded_test.toarray()[-1])
print Predictions

# %%
#L33 Night 
df_train = df_training[Questions+list(df_training.columns[43:47])]
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
Y_train = df_train['L33P'].values
del df_train['L33P']
#ENCODING
X_train = df_train.to_dict('records')
X_tr = []
X_tr.extend(X_train)
#One Hot Encoding 
enc = DictVectorizer(sparse = True)
X_encoded_train =enc.fit_transform(X_tr)
estimator = GradientBoostingClassifier() 
estimator.fit(X_encoded_train.toarray(),Y_train)
from sklearn.externals import joblib
joblib.dump(estimator, 'EstL33.pkl')

# %%
#L32 predict  
from sklearn.externals import joblib
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[Questions+list(df_training.columns[43:47])]
df_test = df_train[1:2]
frames = [ df_DUMB,df_test]
df_WH = pd.concat(frames)

#ENCODING
del df_WH['L33P']
X_test = df_WH.to_dict('records')
X_te = []
X_te.extend(X_test)


encoder = DictVectorizer(sparse = True)
X_encoded_test = encoder.fit_transform(X_te)
clf2 = joblib.load('EstL33.pkl') 
Predictions = clf2.predict(X_encoded_test.toarray()[-1])
Predictions_proba = clf2.predict_proba(X_encoded_test.toarray()[-1])

print Predictions,Predictions_proba[0][0]

# %%
df_test

# %%
import MySQLdb
from pandas.io.sql import frame_query
# Open database connection
db = MySQLdb.connect("localhost","root","","ge_hackathon" )

# prepare a cursor object using cursor() method
cursor = db.cursor()

# Prepare SQL query to INSERT a record into the database.
sql = "SELECT * FROM answers WHERE finished='0'"
data = frame_query(sql, db)
# disconnect from server
db.close()

# %%
#BasicFuntion Night 
import MySQLdb
import pandas
from pandas.io.sql import frame_query
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
def BasicNight():
        db = MySQLdb.connect("localhost","root","","ge_hackathon" )
        cursor = db.cursor()
        sql = "SELECT * FROM answers WHERE finished='1'"
        data = frame_query(sql, db)
        #BasicFuntion Night 

        df_training = data
        df_train = df_training[df_training.columns[2:9]]

        Y_train = df_train['L11P'].values
        del df_train['L11P']
        #ENCODING
        X_train = df_train.to_dict('records')
        X_tr = []
        X_tr.extend(X_train)
        #One Hot Encoding 
        enc = DictVectorizer(sparse = True)
        X_encoded_train =enc.fit_transform(X_tr)
        estimator = GradientBoostingClassifier() 
        estimator.fit(X_encoded_train.toarray(),Y_train)
        from sklearn.externals import joblib
        joblib.dump(estimator, 'Estbasic.pkl')

# %%
#BasicFuntion predict 
from sklearn.externals import joblib
from pandas.io.sql import frame_query
import MySQLdb
import pandas
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction import DictVectorizer 
import pandas as pd
def Basicpred():
    URL = 'DUMB.csv'
    DUMB = pandas.read_csv(URL)
    df_DUMB = DUMB[DUMB.columns[1:7]]

    db = MySQLdb.connect("localhost","root","","ge_hackathon" )
    cursor = db.cursor()
    sql = "SELECT * FROM answers WHERE finished='0'"
    data = frame_query(sql, db)

    df_test = data[data.columns[2:8]]
    frames = [ df_DUMB,df_test]
    df_WH = pd.concat(frames)

    #ENCODING
    X_test = df_WH.to_dict('records')
    X_te = []
    X_te.extend(X_test)


    encoder = DictVectorizer(sparse = True)
    X_encoded_test = encoder.fit_transform(X_te)
    clf2 = joblib.load('Estbasic.pkl') 
    Predictions = clf2.predict(X_encoded_test.toarray()[-1])
    return str(int(Predictions))

# %%
Basicpred()
# Out:
# C:\Users\sai_praneeth7777\Anaconda2\lib\site-packages\ipykernel\__main__.py:18: FutureWarning: frame_query is deprecated, use read_sql
# C:\Users\sai_praneeth7777\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# '21'

# %%
db = MySQLdb.connect("localhost","root","","ge_hackathon" )
cursor = db.cursor()
sql = "SELECT * FROM answers WHERE finished='1'"
data = frame_query(sql, db)
# Out:
# C:\Users\sai_praneeth7777\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: frame_query is deprecated, use read_sql

# %%
data
# Out:
#        id name  Age   BP Morning Sickness Breast discomfort  Sugar  \
# 0       3        26  162               No               Yes     14
# 1       4        35   97               No               Yes     10
# 2       5        38  142               No                No     10
# 3       6        25   44               No               Yes      3
# 4       7        22  105               No                No      6
# 5       8        21  206              Yes                No     10
# 6       9        40    5              Yes               Yes     10
# 7      10        15   94              Yes               Yes     10
# 8      11        15  188               No                No      9
# 9      12        28   41               No               Yes     10
# 10     13        18  156              Yes               Yes      7
# 11     14        36   60              Yes               Yes     13
# 12     15        35   83              Yes               Yes     14
# ...

# %%
db = MySQLdb.connect("localhost","root","","ge_hackathon" )
cursor = db.cursor()
sql = "SELECT * FROM answers WHERE finished='0'"
data = frame_query(sql, db)

# %%
data

# %%
df_train = data[data.columns[2:8]]

# %%
df_train

# %%
df_DUMB = DUMB[df_training.columns[:7]]

# %%
URL = 'DUMB.csv'
DUMB = pandas.read_csv(URL)
df_DUMB = DUMB[DUMB.columns[1:7]]

# %%
df_DUMB
